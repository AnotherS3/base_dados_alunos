# %% [markdown]
# <a href="https://colab.research.google.com/github/AnotherS3/base_dados_alunos/blob/main/quantidade_linhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
basedados = "/content/base_dados_alunos/github - Página1.csv"

with open(basedados,"r") as arquivo:
  qtd_linhas = arquivo.readlines()
print(len(qtd_linhas))
# Out:
# 53
